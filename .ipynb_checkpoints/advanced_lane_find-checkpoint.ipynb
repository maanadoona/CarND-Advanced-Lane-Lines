# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %matplotlib inline

# %%
cal_folder = 'camera_cal/'
cal_files = [f for f in os.listdir(cal_folder)]

fig, axs = plt.subplots(5,4, figsize=(16, 11))
axs = axs.ravel()
print('Num. of Test Images for calibration : {0}'.format(len(cal_files)))

# Test Images
for i, fname in enumerate(cal_files):
    img = cv2.imread(str(cal_folder + fname))
    axs[i].set_title(fname, fontsize=15)
    axs[i].axis('off')
    axs[i].imshow(img)
# Out:
# Num. of Test Images for calibration : 20

# %%
# Find Chessboard Corners
objp = np.zeros((6*9,3), np.float32)
objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

objpoints = [] # 3d points in real world space
imgpoints = [] # 2d points in image plane.

point_num = [[9, 6], [9, 5], [9, 5], [8, 6], [8, 5], [8, 4]]

fig, axs = plt.subplots(5,4, figsize=(16, 11))
axs = axs.ravel()

for i, fname in enumerate(cal_files):
    img = cv2.imread(str(cal_folder + fname))
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Find the chessboard corners
    print(i, fname)
    for num in point_num:
        ret, corners = cv2.findChessboardCorners(gray, tuple(num), None)
        if ret == True:
            objpoints.append(objp)
            
            img_corner = cv2.drawChessboardCorners(img, tuple(num), corners, ret)

            axs[i].set_title(fname + ' ' + str(tuple(num)), fontsize=15)
            axs[i].axis('off')
            axs[i].imshow(img_corner)
            break
# Out:
# 0 calibration7.jpg
# 1 calibration12.jpg
# 2 calibration11.jpg
# 3 calibration8.jpg
# 4 calibration15.jpg
# 5 calibration17.jpg
# 6 calibration10.jpg
# 7 calibration9.jpg
# 8 calibration13.jpg
# 9 calibration5.jpg
# 10 calibration16.jpg
# 11 calibration4.jpg
# 12 calibration1.jpg
# 13 calibration2.jpg
# 14 calibration18.jpg
# 15 calibration6.jpg
# 16 calibration20.jpg
# 17 calibration19.jpg
# 18 calibration14.jpg
# 19 calibration3.jpg
